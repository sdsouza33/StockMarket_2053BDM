# %%
import pandas as pd
import numpy as np
import yfinance as yf
import ta
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.losses import MeanSquaredError

def data_prep(start_date, end_date):
    df = yf.download('AMZN',start_date,end_date)
    APPL = yf.download('AAPL',start_date,end_date)
    MSFT = yf.download('MSFT',start_date,end_date)
    GOOG = yf.download('GOOG',start_date,end_date)
    VIX = yf.download("^VIX", start_date,end_date)
    usdx = yf.download('DX-Y.NYB', start_date,end_date)


    df = df.reset_index()
    df['Date'] = pd.to_datetime(df['Date'])
    df.set_index('Date', inplace=True)

    df['APPL'] = APPL['Close']
    df['MSFT'] = MSFT['Close']
    df['GOOG'] = GOOG['Close']
    df['VIX'] = VIX['Close']
    df['USDX'] = usdx['Close']

    df['RSI'] = ta.momentum.RSIIndicator(df['Close'], window=14).rsi()

    ema12 = df['Close'].ewm(span=12, adjust=False).mean()
    ema26 = df['Close'].ewm(span=26, adjust=False).mean()

    macd = ema12 - ema26
    signal = macd.ewm(span=9, adjust=False).mean()
    histogram = macd - signal

    df['EMA12'] = ema12
    df['EMA26'] = ema26
    df['MACD'] = macd
    df['MACD_signal'] = signal
    df['MACD_hist'] = histogram

    print(df.info)
    df.columns = df.columns.str.replace(' ','_')
    df = df.dropna()
    df.drop(['Open', 'High', 'Low', 'Adj_Close'], axis=1, inplace=True)
    y_data = df['Close']
    df.drop(['Close'], axis=1, inplace=True)
    X_data = df
    return X_data,y_data

start_date = '2022-04-01'
end_date = '2023-03-31'
X, y = data_prep(start_date, end_date)

print("Shape of X:", X.shape)
print("Shape of y:", y.shape)

if X.shape[0] > 0 and y.shape[0] > 0:
    scaler = MinMaxScaler()
    X = scaler.fit_transform(X)
    y_scaler = MinMaxScaler()
    y = y_scaler.fit_transform(y.values.reshape(-1, 1))
else:
    print("Insufficient data for MinMaxScaler")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# <bound method DataFrame.info of                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-04-01  164.149506  165.826996  162.319504  163.559998  163.559998
# 2022-04-04  164.125000  168.394501  163.205505  168.346497  168.346497
# 2022-04-05  167.741501  168.110504  163.266006  164.054993  164.054993
# 2022-04-06  161.650497  162.199997  157.254501  158.755997  158.755997
# 2022-04-07  158.399994  160.078995  154.511505  157.784500  157.784500
# ...                ...         ...         ...         ...         ...
# 2023-03-24   98.070000   98.300003   96.400002   98.129997   98.129997
# 2023-03-27   99.070000   99.339996   97.080002   98.040001   98.040001
# 2023-03-28   98.110001   98.440002   96.290001   97.239998   97.239998
# 2023-03-29   98.690002  100.419998   98.559998  100.250000  100.250000
# 2023-03-30  101.550003  103.040001  101.010002  102.000000  102.000000
#
#               Volume        APPL        MSFT        GOOG        VIX  \
# Date
# 2022-04-01  57090000  174.309998  309.420013  140.699997  19.629999
# 2022-04-04  49882000  178.440002  314.970001  143.642502  18.570000
# 2022-04-05  53728000  175.059998  310.880005  141.063004  21.030001
# 2022-04-06  79056000  171.830002  299.500000  137.175995  22.100000
# 2022-04-07  68136000  172.139999  301.369995  136.464996  21.549999
# ...              ...         ...         ...         ...        ...
# 2023-03-24  56095400  160.250000  280.570007  106.059998  21.740000
# 2023-03-27  46721300  158.279999  276.380005  103.059998  20.600000
# 2023-03-28  38720100  157.649994  275.230011  101.360001  19.969999
# 2023-03-29  49783300  160.770004  280.510010  101.900002  19.120001
# 2023-03-30  53633400  162.360001  284.049988  101.320000  19.020000
#
#                   USDX        RSI       EMA12       EMA26      MACD  \
# Date
# 2022-04-01   98.629997        NaN  163.559998  163.559998  0.000000
# 2022-04-04   98.989998        NaN  164.296382  163.914553  0.381829
# 2022-04-05   99.470001        NaN  164.259245  163.924956  0.334289
# 2022-04-06   99.599998        NaN  163.412592  163.542070 -0.129479
# 2022-04-07   99.750000        NaN  162.546731  163.115583 -0.568852
# ...                ...        ...         ...         ...       ...
# 2023-03-24  103.120003  53.798565   97.373437   96.626142  0.747295
# 2023-03-27  102.860001  53.558891   97.475986   96.730872  0.745113
# 2023-03-28  102.430000  51.368130   97.439680   96.768585  0.671095
# 2023-03-29  102.639999  58.282348   97.872037   97.026468  0.845569
# 2023-03-30  102.139999  61.692414   98.507108   97.394878  1.112230
#
#             MACD_signal  MACD_hist
# Date
# 2022-04-01     0.000000   0.000000
# 2022-04-04     0.076366   0.305463
# 2022-04-05     0.127950   0.206339
# 2022-04-06     0.076465  -0.205943
# 2022-04-07    -0.052599  -0.516253
# ...                 ...        ...
# 2023-03-24     0.177562   0.569734
# 2023-03-27     0.291072   0.454041
# 2023-03-28     0.367077   0.304018
# 2023-03-29     0.462775   0.382794
# 2023-03-30     0.592666   0.519564
#
# [250 rows x 17 columns]>
# Shape of X: (237, 12)
# Shape of y: (237,)

# %%
train_size = int(len(X) * 0.8)
train_X, test_X = X[:train_size], X[train_size:]
train_Y, test_Y = y[:train_size], y[train_size:]

train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))

model = Sequential()
model.add(LSTM(128, activation='tanh', input_shape=(train_X.shape[1], train_X.shape[2
]), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(64, activation='tanh', return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu'))
model.add(Dense(1))
model.compile(loss=MeanSquaredError(), optimizer=Adam())

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=20, verbose=1)
history = model.fit(train_X, train_Y, epochs=100, batch_size=16, validation_data=(test_X, test_Y), callbacks=[early_stop], verbose=2, shuffle=False)

test_loss = model.evaluate(test_X, test_Y, verbose=0)
yhat = model.predict(test_X)

yhat = y_scaler.inverse_transform(yhat)
test_Y = y_scaler.inverse_transform(test_Y)

print('Test loss: ', test_loss)

mae = mean_absolute_error(test_Y, yhat)
rmse = np.sqrt(mean_squared_error(test_Y, yhat))
r2 = r2_score(test_Y, yhat)

print('MAE: ', mae)
print('RMSE: ', rmse)
print('R²: ', r2)
# Out:
# Epoch 1/100
# 12/12 - 5s - loss: 0.2348 - val_loss: 0.0131 - 5s/epoch - 445ms/step
# Epoch 2/100
# 12/12 - 0s - loss: 0.1155 - val_loss: 0.0151 - 82ms/epoch - 7ms/step
# Epoch 3/100
# 12/12 - 0s - loss: 0.0468 - val_loss: 0.0809 - 84ms/epoch - 7ms/step
# Epoch 4/100
# 12/12 - 0s - loss: 0.0278 - val_loss: 0.0359 - 79ms/epoch - 7ms/step
# Epoch 5/100
# 12/12 - 0s - loss: 0.0281 - val_loss: 0.0299 - 79ms/epoch - 7ms/step
# Epoch 6/100
# 12/12 - 0s - loss: 0.0244 - val_loss: 0.0389 - 78ms/epoch - 6ms/step
# Epoch 7/100
# 12/12 - 0s - loss: 0.0181 - val_loss: 0.0288 - 81ms/epoch - 7ms/step
# Epoch 8/100
# 12/12 - 0s - loss: 0.0144 - val_loss: 0.0264 - 80ms/epoch - 7ms/step
# Epoch 9/100
# 12/12 - 0s - loss: 0.0131 - val_loss: 0.0252 - 82ms/epoch - 7ms/step
# Epoch 10/100
# 12/12 - 0s - loss: 0.0099 - val_loss: 0.0153 - 78ms/epoch - 7ms/step
# Epoch 11/100
# 12/12 - 0s - loss: 0.0103 - val_loss: 0.0206 - 84ms/epoch - 7ms/step
# Epoch 12/100
# 12/12 - 0s - loss: 0.0086 - val_loss: 0.0100 - 80ms/epoch - 7ms/step
# Epoch 13/100
# 12/12 - 0s - loss: 0.0085 - val_loss: 0.0197 - 82ms/epoch - 7ms/step
# Epoch 14/100
# 12/12 - 0s - loss: 0.0082 - val_loss: 0.0057 - 89ms/epoch - 7ms/step
# Epoch 15/100
# 12/12 - 0s - loss: 0.0090 - val_loss: 0.0188 - 84ms/epoch - 7ms/step
# Epoch 16/100
# 12/12 - 0s - loss: 0.0084 - val_loss: 0.0049 - 82ms/epoch - 7ms/step
# Epoch 17/100
# 12/12 - 0s - loss: 0.0086 - val_loss: 0.0178 - 77ms/epoch - 6ms/step
# Epoch 18/100
# 12/12 - 0s - loss: 0.0081 - val_loss: 0.0041 - 80ms/epoch - 7ms/step
# Epoch 19/100
# 12/12 - 0s - loss: 0.0077 - val_loss: 0.0145 - 83ms/epoch - 7ms/step
# Epoch 20/100
# 12/12 - 0s - loss: 0.0071 - val_loss: 0.0036 - 77ms/epoch - 6ms/step
# Epoch 21/100
# 12/12 - 0s - loss: 0.0078 - val_loss: 0.0136 - 78ms/epoch - 7ms/step
# Epoch 22/100
# 12/12 - 0s - loss: 0.0070 - val_loss: 0.0030 - 78ms/epoch - 7ms/step
# Epoch 23/100
# 12/12 - 0s - loss: 0.0066 - val_loss: 0.0098 - 79ms/epoch - 7ms/step
# Epoch 24/100
# 12/12 - 0s - loss: 0.0053 - val_loss: 0.0025 - 78ms/epoch - 7ms/step
# Epoch 25/100
# 12/12 - 0s - loss: 0.0064 - val_loss: 0.0104 - 79ms/epoch - 7ms/step
# Epoch 26/100
# 12/12 - 0s - loss: 0.0067 - val_loss: 0.0020 - 100ms/epoch - 8ms/step
# Epoch 27/100
# 12/12 - 0s - loss: 0.0069 - val_loss: 0.0106 - 79ms/epoch - 7ms/step
# Epoch 28/100
# 12/12 - 0s - loss: 0.0073 - val_loss: 0.0021 - 77ms/epoch - 6ms/step
# Epoch 29/100
# 12/12 - 0s - loss: 0.0060 - val_loss: 0.0071 - 80ms/epoch - 7ms/step
# Epoch 30/100
# 12/12 - 0s - loss: 0.0058 - val_loss: 0.0018 - 81ms/epoch - 7ms/step
# Epoch 31/100
# 12/12 - 0s - loss: 0.0061 - val_loss: 0.0057 - 82ms/epoch - 7ms/step
# Epoch 32/100
# 12/12 - 0s - loss: 0.0051 - val_loss: 0.0017 - 78ms/epoch - 6ms/step
# Epoch 33/100
# 12/12 - 0s - loss: 0.0052 - val_loss: 0.0046 - 80ms/epoch - 7ms/step
# Epoch 34/100
# 12/12 - 0s - loss: 0.0039 - val_loss: 0.0016 - 80ms/epoch - 7ms/step
# Epoch 35/100
# 12/12 - 0s - loss: 0.0047 - val_loss: 0.0054 - 79ms/epoch - 7ms/step
# Epoch 36/100
# 12/12 - 0s - loss: 0.0053 - val_loss: 0.0015 - 78ms/epoch - 6ms/step
# Epoch 37/100
# 12/12 - 0s - loss: 0.0037 - val_loss: 0.0020 - 79ms/epoch - 7ms/step
# Epoch 38/100
# 12/12 - 0s - loss: 0.0040 - val_loss: 0.0019 - 78ms/epoch - 6ms/step
# Epoch 39/100
# 12/12 - 0s - loss: 0.0037 - val_loss: 0.0022 - 78ms/epoch - 7ms/step
# Epoch 40/100
# 12/12 - 0s - loss: 0.0036 - val_loss: 0.0015 - 77ms/epoch - 6ms/step
# Epoch 41/100
# 12/12 - 0s - loss: 0.0044 - val_loss: 0.0012 - 78ms/epoch - 6ms/step
# Epoch 42/100
# 12/12 - 0s - loss: 0.0040 - val_loss: 0.0019 - 77ms/epoch - 6ms/step
# Epoch 43/100
# 12/12 - 0s - loss: 0.0036 - val_loss: 0.0011 - 80ms/epoch - 7ms/step
# Epoch 44/100
# 12/12 - 0s - loss: 0.0034 - val_loss: 0.0015 - 78ms/epoch - 7ms/step
# Epoch 45/100
# 12/12 - 0s - loss: 0.0034 - val_loss: 0.0010 - 81ms/epoch - 7ms/step
# Epoch 46/100
# 12/12 - 0s - loss: 0.0029 - val_loss: 9.5552e-04 - 79ms/epoch - 7ms/step
# Epoch 47/100
# 12/12 - 0s - loss: 0.0036 - val_loss: 8.8383e-04 - 78ms/epoch - 7ms/step
# Epoch 48/100
# 12/12 - 0s - loss: 0.0031 - val_loss: 9.0570e-04 - 78ms/epoch - 6ms/step
# Epoch 49/100
# 12/12 - 0s - loss: 0.0039 - val_loss: 0.0013 - 78ms/epoch - 6ms/step
# Epoch 50/100
# 12/12 - 0s - loss: 0.0035 - val_loss: 0.0010 - 80ms/epoch - 7ms/step
# Epoch 51/100
# 12/12 - 0s - loss: 0.0034 - val_loss: 7.1807e-04 - 81ms/epoch - 7ms/step
# Epoch 52/100
# 12/12 - 0s - loss: 0.0035 - val_loss: 7.2245e-04 - 78ms/epoch - 6ms/step
# Epoch 53/100
# 12/12 - 0s - loss: 0.0037 - val_loss: 7.0945e-04 - 90ms/epoch - 7ms/step
# Epoch 54/100
# 12/12 - 0s - loss: 0.0027 - val_loss: 7.9763e-04 - 83ms/epoch - 7ms/step
# Epoch 55/100
# 12/12 - 0s - loss: 0.0029 - val_loss: 8.9145e-04 - 79ms/epoch - 7ms/step
# Epoch 56/100
# 12/12 - 0s - loss: 0.0032 - val_loss: 0.0011 - 80ms/epoch - 7ms/step
# Epoch 57/100
# 12/12 - 0s - loss: 0.0033 - val_loss: 0.0011 - 82ms/epoch - 7ms/step
# Epoch 58/100
# 12/12 - 0s - loss: 0.0040 - val_loss: 5.2600e-04 - 80ms/epoch - 7ms/step
# Epoch 59/100
# 12/12 - 0s - loss: 0.0032 - val_loss: 0.0024 - 81ms/epoch - 7ms/step
# Epoch 60/100
# 12/12 - 0s - loss: 0.0036 - val_loss: 8.1260e-04 - 77ms/epoch - 6ms/step
# Epoch 61/100
# 12/12 - 0s - loss: 0.0042 - val_loss: 7.2527e-04 - 81ms/epoch - 7ms/step
# Epoch 62/100
# 12/12 - 0s - loss: 0.0037 - val_loss: 7.4047e-04 - 78ms/epoch - 7ms/step
# Epoch 63/100
# 12/12 - 0s - loss: 0.0029 - val_loss: 0.0012 - 78ms/epoch - 7ms/step
# Epoch 64/100
# 12/12 - 0s - loss: 0.0035 - val_loss: 6.5680e-04 - 78ms/epoch - 6ms/step
# Epoch 65/100
# 12/12 - 0s - loss: 0.0030 - val_loss: 4.2398e-04 - 77ms/epoch - 6ms/step
# Epoch 66/100
# 12/12 - 0s - loss: 0.0025 - val_loss: 6.8966e-04 - 78ms/epoch - 6ms/step
# Epoch 67/100
# 12/12 - 0s - loss: 0.0030 - val_loss: 0.0013 - 85ms/epoch - 7ms/step
# Epoch 68/100
# 12/12 - 0s - loss: 0.0033 - val_loss: 4.1920e-04 - 91ms/epoch - 8ms/step
# Epoch 69/100
# 12/12 - 0s - loss: 0.0026 - val_loss: 6.0335e-04 - 89ms/epoch - 7ms/step
# Epoch 70/100
# 12/12 - 0s - loss: 0.0027 - val_loss: 4.3223e-04 - 86ms/epoch - 7ms/step
# Epoch 71/100
# 12/12 - 0s - loss: 0.0027 - val_loss: 6.9438e-04 - 81ms/epoch - 7ms/step
# Epoch 72/100
# 12/12 - 0s - loss: 0.0025 - val_loss: 4.9084e-04 - 79ms/epoch - 7ms/step
# Epoch 73/100
# 12/12 - 0s - loss: 0.0030 - val_loss: 0.0010 - 80ms/epoch - 7ms/step
# Epoch 74/100
# 12/12 - 0s - loss: 0.0023 - val_loss: 7.1454e-04 - 82ms/epoch - 7ms/step
# Epoch 75/100
# 12/12 - 0s - loss: 0.0032 - val_loss: 6.9234e-04 - 132ms/epoch - 11ms/step
# Epoch 76/100
# 12/12 - 0s - loss: 0.0030 - val_loss: 0.0019 - 87ms/epoch - 7ms/step
# Epoch 77/100
# 12/12 - 0s - loss: 0.0044 - val_loss: 6.2632e-04 - 86ms/epoch - 7ms/step
# Epoch 78/100
# 12/12 - 0s - loss: 0.0029 - val_loss: 0.0014 - 84ms/epoch - 7ms/step
# Epoch 79/100
# 12/12 - 0s - loss: 0.0055 - val_loss: 3.2912e-04 - 79ms/epoch - 7ms/step
# Epoch 80/100
# 12/12 - 0s - loss: 0.0032 - val_loss: 0.0029 - 78ms/epoch - 7ms/step
# Epoch 81/100
# 12/12 - 0s - loss: 0.0046 - val_loss: 0.0011 - 78ms/epoch - 7ms/step
# Epoch 82/100
# 12/12 - 0s - loss: 0.0046 - val_loss: 0.0030 - 80ms/epoch - 7ms/step
# Epoch 83/100
# 12/12 - 0s - loss: 0.0048 - val_loss: 0.0013 - 78ms/epoch - 7ms/step
# Epoch 84/100
# 12/12 - 0s - loss: 0.0035 - val_loss: 0.0021 - 79ms/epoch - 7ms/step
# Epoch 85/100
# 12/12 - 0s - loss: 0.0029 - val_loss: 3.5221e-04 - 90ms/epoch - 8ms/step
# Epoch 86/100
# 12/12 - 0s - loss: 0.0022 - val_loss: 3.2189e-04 - 84ms/epoch - 7ms/step
# Epoch 87/100
# 12/12 - 0s - loss: 0.0024 - val_loss: 3.3573e-04 - 89ms/epoch - 7ms/step
# Epoch 88/100
# 12/12 - 0s - loss: 0.0024 - val_loss: 4.8635e-04 - 80ms/epoch - 7ms/step
# Epoch 89/100
# 12/12 - 0s - loss: 0.0024 - val_loss: 6.8329e-04 - 81ms/epoch - 7ms/step
# Epoch 90/100
# 12/12 - 0s - loss: 0.0024 - val_loss: 3.3825e-04 - 82ms/epoch - 7ms/step
# Epoch 91/100
# 12/12 - 0s - loss: 0.0026 - val_loss: 4.1653e-04 - 85ms/epoch - 7ms/step
# Epoch 92/100
# 12/12 - 0s - loss: 0.0021 - val_loss: 4.5290e-04 - 82ms/epoch - 7ms/step
# Epoch 93/100
# 12/12 - 0s - loss: 0.0019 - val_loss: 3.5768e-04 - 82ms/epoch - 7ms/step
# Epoch 94/100
# 12/12 - 0s - loss: 0.0020 - val_loss: 4.0240e-04 - 78ms/epoch - 6ms/step
# Epoch 95/100
# 12/12 - 0s - loss: 0.0019 - val_loss: 3.1961e-04 - 79ms/epoch - 7ms/step
# Epoch 96/100
# 12/12 - 0s - loss: 0.0022 - val_loss: 8.5220e-04 - 77ms/epoch - 6ms/step
# Epoch 97/100
# 12/12 - 0s - loss: 0.0018 - val_loss: 7.5002e-04 - 78ms/epoch - 7ms/step
# Epoch 98/100
# 12/12 - 0s - loss: 0.0025 - val_loss: 0.0020 - 82ms/epoch - 7ms/step
# Epoch 99/100
# 12/12 - 0s - loss: 0.0034 - val_loss: 4.9557e-04 - 79ms/epoch - 7ms/step
# Epoch 100/100
# 12/12 - 0s - loss: 0.0029 - val_loss: 3.7625e-04 - 82ms/epoch - 7ms/step
# 2/2 [==============================] - 1s 4ms/step
# Test loss:  0.00037624858669005334
# MAE:  1.0360245704650868
# RMSE:  1.2894435330320342
# R²:  0.898129161836906

# %%
n_future_days = 10
predictions = []

for i in range(n_future_days):
    input_data = test_X[-1].reshape((1, test_X.shape[1], test_X.shape[2]))
    next_day_predicted_price_scaled = model.predict(input_data)
    next_day_predicted_price = y_scaler.inverse_transform(next_day_predicted_price_scaled)
    predictions.append(next_day_predicted_price[0][0])

    input_data[0, 0, :-1] = next_day_predicted_price_scaled[0, 0]
    test_X = np.concatenate((test_X, input_data))
print(f"Predicted closing prices for the next {n_future_days} days: {predictions}")
# Out:
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# Predicted closing prices for the next 10 days: [103.92395, 104.052925, 104.216415, 104.42405, 104.688324, 105.02567, 105.45788, 106.014206, 106.734535, 107.67432]
